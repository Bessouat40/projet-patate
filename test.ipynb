# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Premier jeu de données

# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/labess40/dev/projet-patate/back/data/REGIME AG1.xlsx', engine="openpyxl", sheet_name="ALIMENTS LISTE")

# %%
df
# Out:
#                          ALIMENT  LYS (mg)  PROTEINES (g)  CALORIES   \
# 0                            NaN       NaN            NaN        NaN
# 1                            ail     363.0            6.0      145.0
# 2                        abricot      69.0            0.9       45.0
# 3             amande au chocolat     335.0            4.3      168.0
# 4                        amandes     580.0           24.0      611.0
# ..                           ...       ...            ...        ...
# 170  yaourt panna cotta saveur U     150.0            1.9      273.0
# 171  yaourt perle de lait nature     256.0            3.2      115.0
# 172          yaourt petit suisse     900.0            9.1      136.0
# 173         yaourt petits filous     328.0            4.1      131.0
# 174       yaourt viennois nestlé     250.0            3.1      139.0
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# ...

# %%
df_final = df[df.columns[:4]]
df_final = df_final.dropna(axis=0, how="all")
df_final = df_final.fillna(0)

# %%
df_final.columns = ["ALIMENT", "LYS", "PROTEINES", "CALORIES"]

# %%
df_final
# Out:
#                          ALIMENT    LYS  PROTEINES  CALORIES
# 1                            ail  363.0        6.0     145.0
# 2                        abricot   69.0        0.9      45.0
# 3             amande au chocolat  335.0        4.3     168.0
# 4                        amandes  580.0       24.0     611.0
# 5                         ananas   35.0        0.5      59.0
# ..                           ...    ...        ...       ...
# 170  yaourt panna cotta saveur U  150.0        1.9     273.0
# 171  yaourt perle de lait nature  256.0        3.2     115.0
# 172          yaourt petit suisse  900.0        9.1     136.0
# 173         yaourt petits filous  328.0        4.1     131.0
# 174       yaourt viennois nestlé  250.0        3.1     139.0
#
# [174 rows x 4 columns]

# %%
df_final.to_csv('/Users/labess40/dev/projet-patate/back/data/aliments.csv', index=False)

# %% [markdown]
# ## Deuxième jeu de données

# %%
import pandas as pd
path = r"/Users/labess40/dev/projet-patate/back/data/table_nat_2020.xls"

df = pd.read_excel(path)

# %%
df[ "Glucides (g/100 g)"]
# Out:
# 0       36,6
# 1       7,74
# 2        6,4
# 3       3,95
# 4        9,9
#         ...
# 3181    12,5
# 3182    88,3
# 3183    81,1
# 3184    73,3
# 3185      85
# Name: Glucides (g/100 g), Length: 3186, dtype: object

# %%
columns = ["alim_nom_fr", "Energie, Règlement UE N° 1169/2011 (kcal/100 g)", "Protéines, N x 6.25 (g/100 g)", "Glucides (g/100 g)", "Lipides (g/100 g)", "Fructose (g/100 g)", "Sucres (g/100 g)", "Galactose (g/100 g)", "Glucose (g/100 g)", "Lactose (g/100 g)", "Maltose (g/100 g)", "Saccharose (g/100 g)", "Amidon (g/100 g)"]

# %%
df_columns_filter = df[columns]
renamed_columns = ["ALIMENT", "ENERGIE", "PROTEINES", "GLUCIDES", "LIPIDES", "FRUCTOSE", "SUCRES", "GALACTOSE", "GLUCOSE", "LACTOSE", "MALTOSE", "SACCHAROSE", "AMIDON"]
df_columns_filter.columns = renamed_columns
df_columns_filter
# Out:
#                                                 ALIMENT ENERGIE PROTEINES  \
# 0                               Dessert (aliment moyen)     NaN      4,61
# 1                 Salade de thon et légumes, appertisée       -      9,15
# 2     Salade composée avec viande ou poisson, appert...       -      8,06
# 3                  Champignons à la grecque, appertisés       -      2,08
# 4                Salade de pommes de terre, fait maison       -      2,68
# ...                                                 ...     ...       ...
# 3181  Dessert lacté infantile nature sucré ou aux fr...     100      3,13
# 3182  Céréales instantanées, poudre à reconstituer, ...     393       5,1
# 3183  Céréales instantanées, poudre à reconstituer, ...     391        10
# 3184                                  Biscuit pour bébé     439       7,5
# 3185                          Poudre cacaotée pour bébé     396       8,5
#
#      GLUCIDES LIPIDES FRUCTOSE SUCRES GALACTOSE GLUCOSE LACTOSE MALTOSE  \
# ...

# %%
df_columns_filter.isna().sum()
# Out:
# ALIMENT        0
# ENERGIE       17
# PROTEINES      1
# GLUCIDES       1
# LIPIDES        1
# FRUCTOSE      39
# SUCRES         9
# GALACTOSE     84
# GLUCOSE       38
# LACTOSE       45
# MALTOSE       41
# SACCHAROSE    38
# AMIDON        36
# dtype: int64

# %%
without_nan_df = df_columns_filter.dropna()
for column in filter(lambda x : x!='Aliment', renamed_columns):
    without_nan_df[column] = without_nan_df[column].replace('-', "0")

without_nan_df
# Out:
# /var/folders/21/b_d74zx567v6lvf8gnmcn52m0000gn/T/ipykernel_18084/796407851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   without_nan_df[column] = without_nan_df[column].replace('-', "0")
#                                                 ALIMENT ENERGIE PROTEINES  \
# 1                 Salade de thon et légumes, appertisée       0      9,15
# 2     Salade composée avec viande ou poisson, appert...       0      8,06
# 3                  Champignons à la grecque, appertisés       0      2,08
# 4                Salade de pommes de terre, fait maison       0      2,68
# 5             Taboulé ou Salade de couscous, préemballé     179      4,88
# ...                                                 ...     ...       ...
# ...

# %%
def filterNumeric(str_value) :
    try :
        return re.findall(r'([\d,.]+)',str_value)[0].replace(',', '.')
    except :
        return "0"

# %%
import re

for column in renamed_columns[1:] :
    without_nan_df[column] = pd.to_numeric(without_nan_df[column].apply(lambda x : filterNumeric(str(x))))

without_nan_df
# Out:
# /var/folders/21/b_d74zx567v6lvf8gnmcn52m0000gn/T/ipykernel_18084/3052947479.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   without_nan_df[column] = pd.to_numeric(without_nan_df[column].apply(lambda x : filterNumeric(str(x))))
#                                                 ALIMENT  ENERGIE  PROTEINES  \
# 1                 Salade de thon et légumes, appertisée      0.0       9.15
# 2     Salade composée avec viande ou poisson, appert...      0.0       8.06
# 3                  Champignons à la grecque, appertisés      0.0       2.08
# 4                Salade de pommes de terre, fait maison      0.0       2.68
# 5             Taboulé ou Salade de couscous, préemballé    179.0       4.88
# ...

# %%
without_nan_df.to_csv('/Users/labess40/dev/projet-patate/back/data/aliments2_2020.csv', index=False)

# %% [markdown]
# # Intake calcul

# %%
from src.aliment import Aliment
from src.configuration import Configuration

Configuration("./data/aliments.csv")

ail = Aliment("ail", 300)
ananas = Aliment("ananas", 300)

# %%
ail.proteines
# Out:
# 18.0

# %%
Aliment._instances
# Out:
# {'ananas': <src.aliment.Aliment at 0x10b463050>,
#  'ail': <src.aliment.Aliment at 0x106381090>}

# %% [markdown]
# # Menu definition

# %%
from back import Menu
from back import Configuration

Configuration("/Users/labess40/dev/projet-patate/back/data/aliments.csv")

food_dict = {"abricot":80, "amandes":100}#, "pignons de pins":100}

menu = Menu(food_dict)
menu.intakes
# Out:
# {'proteines': 24.72, 'lysine': 635.2, 'calories': 647.0}

# %% [markdown]
# # Database

# %%
from sqlalchemy import create_engine, MetaData

engine = create_engine("postgresql+psycopg2://postgres:postgres@172.21.0.2:5432/foodDB")
conn = engine.connect()
add_data = []

data = conn.execute("SELECT * FROM weekMenus").fetchall()
